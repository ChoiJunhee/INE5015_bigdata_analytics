# %%
import pandas as pd

# %%
df=pd.read_csv('[1]_KBS_STD_All1.csv')

# %%
df.head()
# Out:
#                Time  Pass/Fail         0         1         2         3  \
# 0  2008-07-19 11:55         -1  0.553762  0.536407  0.363047  0.400391
# 1  2008-07-19 12:32         -1  0.734152  0.562319  0.542184  0.554681
# 2  2008-07-19 13:17          1  0.280271  0.677912  0.282549  0.509840
# 3  2008-07-19 14:43         -1  0.436349  0.289131  0.613892  0.516119
# 4  2008-07-19 15:22         -1  0.557406  0.494676  0.468462  0.583540
#
#           4         5         6         7  ...       104       105       106  \
# 0  0.597928  0.697262  0.455571  0.570166  ...  1.000000  0.387000  0.210414
# 1  0.588162  0.399881  0.589906  0.360453  ...  0.892680  0.582542  0.163981
# 2  0.585449  0.492738  0.454770  0.336226  ...  0.445973  0.630513  0.227312
# 3  0.576552  0.441786  0.339413  0.358962  ...  0.398569  0.454575  0.227783
# 4  0.573079  0.429405  0.469436  0.514564  ...  0.604161  0.338822  0.210571
#
#         107    108       109       110       111       112       113
# ...

# %%
df.hist(by='Time',column='Pass/Fail',figsize=[200,200])
# Out:
# array([[<AxesSubplot:title={'center':'2008-01-08 10:20'}>,
#         <AxesSubplot:title={'center':'2008-01-08 10:26'}>,
#         <AxesSubplot:title={'center':'2008-01-08 11:28'}>, ...,
#         <AxesSubplot:title={'center':'2008-01-10 15:16'}>,
#         <AxesSubplot:title={'center':'2008-01-10 16:43'}>,
#         <AxesSubplot:title={'center':'2008-01-10 19:57'}>],
#        [<AxesSubplot:title={'center':'2008-01-10 1:11'}>,
#         <AxesSubplot:title={'center':'2008-01-10 21:15'}>,
#         <AxesSubplot:title={'center':'2008-01-10 21:50'}>, ...,
#         <AxesSubplot:title={'center':'2008-02-09 15:29'}>,
#         <AxesSubplot:title={'center':'2008-02-09 16:10'}>,
#         <AxesSubplot:title={'center':'2008-02-09 16:50'}>],
#        [<AxesSubplot:title={'center':'2008-02-09 16:54'}>,
#         <AxesSubplot:title={'center':'2008-02-09 16:58'}>,
#         <AxesSubplot:title={'center':'2008-02-09 17:10'}>, ...,
#         <AxesSubplot:title={'center':'2008-02-10 10:03'}>,
# ...
