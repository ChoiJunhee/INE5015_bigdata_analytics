# %%
import pandas as pd

# %%
df=pd.read_csv('std10_fail.csv')

# %%
df.head()
# Out:
#                Time  Pass/Fail       F0       F1         F2         F3  \
# 0  2008-07-19 13:17          1  2932.61  2559.94  2186.4111  1698.0172
# 1  2008-07-19 21:57          1  2994.05  2548.21  2195.1222  1046.1468
# 2  2008-07-19 22:52          1  2928.84  2479.40  2196.2111  1605.7578
# 3  2008-07-21 11:53          1  2963.97  2629.48  2224.6222   947.7739
# 4  2008-07-25 15:23          1  2884.74  2514.54  2160.3667   899.9488
#
#        F4        F6       F12      F14  ...    F568     F569      F570  \
# 0  1.5102   95.4878  202.0179   9.5157  ...  0.4119  68.8489  535.0245
# 1  1.3204  103.3400  201.7125  11.8566  ...  3.4822  15.4411  532.1764
# 2  0.9959   97.9156  202.1264   9.1084  ...  1.2567  13.0129  533.7464
# 3  1.2924  104.8489  195.3787   9.7561  ...     NaN      NaN  532.6446
# 4  1.4022  105.4978  196.1842  11.6229  ...     NaN      NaN  536.0054
#
#       F572    F574    F576     F577      F581    F585      F589
# ...

# %%
df.hist(by='Time',column='Pass/Fail',figsize=[200,200])
# Out:
# array([[<AxesSubplot:title={'center':'2008-01-08 5:52'}>,
#         <AxesSubplot:title={'center':'2008-01-09 19:54'}>,
#         <AxesSubplot:title={'center':'2008-01-10 5:56'}>,
#         <AxesSubplot:title={'center':'2008-02-10 14:07'}>,
#         <AxesSubplot:title={'center':'2008-02-10 14:10'}>,
#         <AxesSubplot:title={'center':'2008-02-10 21:32'}>,
#         <AxesSubplot:title={'center':'2008-02-10 3:17'}>,
#         <AxesSubplot:title={'center':'2008-02-10 9:10'}>,
#         <AxesSubplot:title={'center':'2008-03-09 1:15'}>,
#         <AxesSubplot:title={'center':'2008-04-08 0:39'}>],
#        [<AxesSubplot:title={'center':'2008-04-08 20:58'}>,
#         <AxesSubplot:title={'center':'2008-04-10 23:18'}>,
#         <AxesSubplot:title={'center':'2008-05-08 7:12'}>,
#         <AxesSubplot:title={'center':'2008-05-10 0:33'}>,
#         <AxesSubplot:title={'center':'2008-05-10 15:30'}>,
#         <AxesSubplot:title={'center':'2008-05-10 15:35'}>,
# ...
