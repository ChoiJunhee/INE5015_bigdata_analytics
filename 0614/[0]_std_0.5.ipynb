# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os.path

# %%
pd=pd.read_csv('[0]_std_0.5.csv')

# %%
features = list(pd.columns[1:])

plt.figure( figsize=(40,250))
for i, feature in enumerate(features) :
    plt.subplot(33 ,4 ,i+1)
    plt.hist(pd[feature],density=1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-025c30c3747d> in <module>
#       3 plt.figure( figsize=(40,250))
#       4 for i, feature in enumerate(features) :
# ----> 5     plt.subplot(32 ,4 ,i+1)
#       6     plt.hist(pd[feature],density=1)
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
# ...
